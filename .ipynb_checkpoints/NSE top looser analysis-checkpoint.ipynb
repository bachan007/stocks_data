# %% [markdown]
# ## In this code, the analysis of the top looser stock has been done

# %%
import pandas as pd
import numpy as np
from nsetools import Nse
import yfinance as yf
import datetime as dt
from dateutil.relativedelta import relativedelta
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings('ignore')

# %%
nse = Nse()

# %%
## Getting the list of stock tickers with their name
stock_codes = pd.Series(nse.get_stock_codes())

# %%
# stock_codes

# %%
top_looser = nse.get_top_losers()[0]

# %%
# top_looser

# %%
company = nse.get_quote(top_looser['symbol'])['companyName']

# %%
print(f"NSE Top looser on last traded day : {company}, with decline in price by {top_looser['netPrice']}%")
# Out:
# NSE Top looser on last traded day : HCL Technologies Limited, with decline in price by -6.50%

# %%
# nse.get_quote(top_looser['symbol'])

# %%
end_date = dt.datetime.now()
start_date = (end_date-relativedelta(years=5)).strftime('%Y-%m-%d') # past five years performance

# %%
end_date = end_date.strftime('%Y-%m-%d')

# %%
# Daywise data of the company
df = yf.download(f"{top_looser['symbol']}.NS",start_date,end_date)
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
df.head()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2017-12-11  437.250000  441.000000  435.875000  440.000000  396.314758
# 2017-12-12  440.500000  440.899994  435.125000  437.600006  394.153046
# 2017-12-13  435.000000  436.774994  431.524994  433.174988  390.167480
# 2017-12-14  431.500000  442.524994  431.100006  441.424988  397.598328
# 2017-12-15  444.450012  448.225006  442.500000  445.899994  401.628937
#
#              Volume
# Date
# 2017-12-11  1597008
# 2017-12-12  2921624
# 2017-12-13  8609940
# 2017-12-14  6365040
# 2017-12-15  4469222

# %%
plt.figure(figsize=(12,8))
plt.plot(df.index,df['Adj Close'])
plt.title(f"Price chart for {company}")
plt.xlabel("year")
plt.ylabel("Price in INR")
plt.show()

# %%
# 100 days Moving Average --> average of last 100 days adj close price
df['100dma'] = df['Adj Close'].rolling(window=100, min_periods=0).mean()

# %%
df.head()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2017-12-11  437.250000  441.000000  435.875000  440.000000  396.314758
# 2017-12-12  440.500000  440.899994  435.125000  437.600006  394.153046
# 2017-12-13  435.000000  436.774994  431.524994  433.174988  390.167480
# 2017-12-14  431.500000  442.524994  431.100006  441.424988  397.598328
# 2017-12-15  444.450012  448.225006  442.500000  445.899994  401.628937
#
#              Volume      100dma
# Date
# 2017-12-11  1597008  396.314758
# 2017-12-12  2921624  395.233902
# 2017-12-13  8609940  393.545095
# 2017-12-14  6365040  394.558403
# 2017-12-15  4469222  395.972510

# %%
plt.figure(figsize=(12,8))
plt.plot(df.index,df[['Adj Close','100dma']])
plt.title(f"100 DMA vs Adj Close for {company}")
plt.xlabel("Date")
plt.ylabel('Price in INR')
plt.show()

# %%
# 221 days Moving Average --> average of last 100 days adj close price
df['221dma'] = df['Adj Close'].rolling(window=221, min_periods=0).mean()

# %%
plt.figure(figsize=(12,8))
plt.plot(df.index,df[['Adj Close','100dma','221dma']])
plt.title(f"100 DMA vs 221 DMA vs Adj Close for {company}")
plt.legend(['Adj Close','100dma','221dma'])
plt.xlabel("Date")
plt.ylabel('Price in INR')
plt.show()

# %%
plt.figure(figsize=(12,8))
ax1 = plt.subplot2grid((7,1),(0,0),rowspan=5,colspan=1)
ax2 = plt.subplot2grid((7,1),(5,0),rowspan=2,colspan=1, sharex=ax1)
ax1.plot(df.index,df['Adj Close'])
ax1.plot(df.index,df['100dma'])
ax1.plot(df.index,df['221dma'])
ax2.bar(df.index,df['Volume'])
plt.show()
