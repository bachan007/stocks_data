# %% [markdown]
# ## In this script, the basic functionalities of nsetools have been explored

# %%
# pip install nsetools

# %%
# To update to the latest version
# pip install nsetools --upgrade

# %%
from nsetools import Nse

# %%
nse = Nse()

# %%
print(nse)
# Out:
# Driver Class for National Stock Exchange (NSE)

# %%
help(nse)
# Out:
# Help on Nse in module nsetools.nse object:
#
# class Nse(nsetools.bases.AbstractBaseExchange)
#  |  class which implements all the functionality for
#  |  National Stock Exchange
#  |
#  |  Method resolution order:
#  |      Nse
#  |      nsetools.bases.AbstractBaseExchange
#  |      builtins.object
#  |
#  |  Methods defined here:
#  |
#  |  __init__(self)
#  |      Initialize self.  See help(type(self)) for accurate signature.
#  |
#  |  __str__(self)
#  |      string representation of object
#  |      :return: string
#  |
#  |  build_url_for_quote(self, code)
#  |      builds a url which can be requested for a given stock code
#  |      :param code: string containing stock code.
#  |      :return: a url object
#  |
#  |  clean_server_response(self, resp_dict)
#  |      cleans the server reponse by replacing:
#  |          '-'     -> None
#  |          '1,000' -> 1000
#  |      :param resp_dict:
#  |      :return: dict with all above substitution
#  |
# ...

# %%
# qte = nse.get_quote('TECHM')
# qte

# %%
# index list
nse.get_index_list()
# Out:
# ['NIFTY 50 Pre Open',
#  'NIFTY 50',
#  'NIFTY NEXT 50',
#  'NIFTY100 LIQ 15',
#  'NIFTY BANK',
#  'INDIA VIX',
#  'NIFTY 100',
#  'NIFTY 500',
#  'NIFTY MIDCAP 100',
#  'NIFTY MIDCAP 50',
#  'NIFTY INFRA',
#  'NIFTY REALTY',
#  'NIFTY ENERGY',
#  'NIFTY FMCG',
#  'NIFTY MNC',
#  'NIFTY PHARMA',
#  'NIFTY PSE',
#  'NIFTY PSU BANK',
#  'NIFTY SERV SECTOR',
#  'NIFTY IT',
#  'NIFTY SMLCAP 100',
#  'NIFTY 200',
#  'NIFTY AUTO',
#  'NIFTY MEDIA',
#  'NIFTY METAL',
#  'NIFTY DIV OPPS 50',
#  'NIFTY COMMODITIES',
#  'NIFTY CONSUMPTION',
#  'NIFTY CPSE',
#  'NIFTY FIN SERVICE',
#  'NIFTY GROWSECT 15',
#  'NIFTY50 VALUE 20',
#  'NIFTY50 TR 2X LEV',
#  'NIFTY50 PR 2X LEV',
#  'NIFTY50 TR 1X INV',
#  'NIFTY50 PR 1X INV',
#  'NIFTY ALPHA 50',
#  'NIFTY50 EQL WGT',
#  'NIFTY100 EQL WGT',
#  'NIFTY100 LOWVOL30',
#  'NIFTY MID LIQ 15',
#  'NIFTY PVT BANK',
#  'NIFTY100 QUALTY30',
#  'NIFTY GS 8 13YR',
#  'NIFTY GS 10YR',
#  'NIFTY GS 10YR CLN',
#  'NIFTY GS 4 8YR',
#  'NIFTY GS 11 15YR',
# ...

# %%
nse.get_index_quote('NIFTY REALTY')
# Out:
# {'name': 'NIFTY REALTY',
#  'lastPrice': 447.55,
#  'change': '-6.80',
#  'pChange': '-1.50',
#  'imgFileName': 'NIFTY_REALTY_open.png'}

# %%
nse.get_top_gainers()
# Out:
# [{'symbol': 'NESTLEIND',
#   'series': 'EQ',
#   'openPrice': 19968.0,
#   'highPrice': 20294.95,
#   'lowPrice': 19844.2,
#   'ltp': 20260.0,
#   'previousPrice': 19805.35,
#   'netPrice': 2.3,
#   'tradedQuantity': 76755.0,
#   'turnoverInLakhs': 15430.6,
#   'lastCorpAnnouncementDate': '31-Oct-2022',
#   'lastCorpAnnouncement': 'Interim Dividend - Rs 120 Per Share'},
#  {'symbol': 'SUNPHARMA',
#   'series': 'EQ',
#   'openPrice': 980.8,
#   'highPrice': 997.0,
#   'lowPrice': 980.0,
#   'ltp': 993.0,
#   'previousPrice': 980.8,
#   'netPrice': 1.24,
#   'tradedQuantity': 4231753.0,
#   'turnoverInLakhs': 41916.36,
#   'lastCorpAnnouncementDate': '19-Aug-2022',
#   'lastCorpAnnouncement': 'Dividend - Rs 3 Per Share'},
#  {'symbol': 'ITC',
#   'series': 'EQ',
#   'openPrice': 339.75,
#   'highPrice': 342.5,
#   'lowPrice': 338.0,
#   'ltp': 342.0,
#   'previousPrice': 338.4,
#   'netPrice': 1.06,
#   'tradedQuantity': 8132228.0,
#   'turnoverInLakhs': 27696.74,
# ...

# %%
nse.get_top_losers()
# Out:
# [{'symbol': 'HCLTECH',
#   'series': 'EQ',
#   'openPrice': 1075.0,
#   'highPrice': 1075.0,
#   'lowPrice': 1020.7,
#   'ltp': 1029.8,
#   'previousPrice': 1101.35,
#   'netPrice': '-6.50',
#   'tradedQuantity': 12415478.0,
#   'turnoverInLakhs': 128678.98,
#   'lastCorpAnnouncementDate': '19-Oct-2022',
#   'lastCorpAnnouncement': 'Interim Dividend - Rs 10 Per Share'},
#  {'symbol': 'TECHM',
#   'series': 'EQ',
#   'openPrice': 1073.95,
#   'highPrice': 1075.7,
#   'lowPrice': 1030.2,
#   'ltp': 1036.75,
#   'previousPrice': 1074.15,
#   'netPrice': '-3.48',
#   'tradedQuantity': 3138360.0,
#   'turnoverInLakhs': 32797.12,
#   'lastCorpAnnouncementDate': '09-Nov-2022',
#   'lastCorpAnnouncement': 'Special Dividend - Rs 18 Per Share'},
#  {'symbol': 'INFY',
#   'series': 'EQ',
#   'openPrice': 1628.0,
#   'highPrice': 1628.0,
#   'lowPrice': 1561.1,
#   'ltp': 1570.2,
#   'previousPrice': 1620.15,
#   'netPrice': '-3.08',
#   'tradedQuantity': 8880658.0,
# ...

# %%
## Getting the symbols of all the listed companies on NSE
nse.get_stock_codes()
# Out:
# {'SYMBOL': 'NAME OF COMPANY',
#  '20MICRONS': '20 Microns Limited',
#  '21STCENMGM': '21st Century Management Services Limited',
#  '3IINFOLTD': '3i Infotech Limited',
#  '3MINDIA': '3M India Limited',
#  '3PLAND': '3P Land Holdings Limited',
#  '4THDIM': 'Fourth Dimension Solutions Limited',
#  '5PAISA': '5Paisa Capital Limited',
#  '63MOONS': '63 moons technologies limited',
#  'A2ZINFRA': 'A2Z Infra Engineering Limited',
#  'AAATECH': 'AAA Technologies Limited',
#  'AAKASH': 'Aakash Exploration Services Limited',
#  'AAREYDRUGS': 'Aarey Drugs & Pharmaceuticals Limited',
#  'AARON': 'Aaron Industries Limited',
#  'AARTIDRUGS': 'Aarti Drugs Limited',
#  'AARTIIND': 'Aarti Industries Limited',
#  'AARTISURF': 'Aarti Surfactants Limited',
#  'AARVEEDEN': 'Aarvee Denims & Exports Limited',
#  'AARVI': 'Aarvi Encon Limited',
#  'AAVAS': 'Aavas Financiers Limited',
#  'ABAN': 'Aban Offshore Limited',
#  'ABB': 'ABB India Limited',
#  'ABBOTINDIA': 'Abbott India Limited',
# ...

# %%
nse.is_valid_code('techm')
# Out:
# True
